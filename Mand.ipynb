# %%
""" 

Written by Femke Mostert (GitHub: Nademaaltijd) for SimpleText @ CLEF 2022


The 'no-check-certificate' link as described in the GUI API documentation is used, 
which causes a warning. The DBLP data is still accessible despite the SSL warning. 
    
There are several search parameters you can use: size, text queries, and boolean 
queries. Below are a few example queries from the API documentation, remove hash 
before query to use (make sure to only have one query active). 

"""

import requests
import pandas as pd


# example of a text query
query = {'q':'algebra', 'size':'4'}


# example of a boolean query which retrieves doc with id 1494645067
# query = {'q':'_id:1494645067', 'size':'1'}


# example of a boolean query which retrieves docs which refer to 1584898773
# query = {'q':'references:1584898773', 'size':'1'}


# example of a boolean query which retrieves all documents which title 
# contains geometric or with a field of subject name equal to "
# Computer science" and another including algebra but none equal to Graph
# query = {'q':'(( fos.name: "Computer science" AND fos.name:*algebra* AND NOT fos.name:Graph ) OR title:*geometric* )', 'size':'10'}

url = 'https://inex:qatc2011@guacamole.univ-avignon.fr/dblp1/_search?'
with requests.get(url, params=query, verify=False) as f:
    dump = f.json()


# convert entries to dataframe (NOT FINISHED, NEED TO FLATTEN NESTED LIST)

df = pd.DataFrame(dump)
# print('Data frame: \n', df)
papers = dump['hits']['hits']
papers
# Out:
# C:\Users\mink-\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'guacamole.univ-avignon.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'_index': 'dblp1',
#   '_type': '_doc',
#   '_id': '2956661043',
#   '_score': 13.840944,
#   '_source': {'id': 2956661043,
#    'authors': [{'name': 'Tihana Babic',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 2810252259},
#     {'name': 'Andrej Lackovic',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 2956200875},
#     {'name': 'Martina Matejic',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 2946534387}],
#    'title': 'Critical Thinking and Creative Thinking - the self-assessment of Algebra University College students',
#    'year': 2019,
#    'n_citation': 0,
#    'page_start': '843',
#    'page_end': '848',
#    'doc_type': 'Conference',
#    'publisher': 'IEEE',
#    'volume': '',
#    'issue': '',
#    'doi': '10.23919/MIPRO.2019.8757107',
#    'fos': [{'name': 'Self-assessment', 'w': 0.46724},
#     {'name': 'Conceptual economy', 'w': 0.56208},
#     {'name': 'Algebra', 'w': 0.33293},
#     {'name': 'Computer science', 'w': 0.38773},
#     {'name': 'Outsourcing', 'w': 0.46447},
#     {'name': 'Critical thinking', 'w': 0.65965},
#     {'name': 'Self', 'w': 0.47672},
#     {'name': 'Human capital', 'w': 0.50811},
#     {'name': 'Creativity', 'w': 0.55269},
#     {'name': 'Information Age', 'w': 0.51277}],
#    'venue': {'raw': 'International Convention on Information and Communication Technology, Electronics and Microelectronics',
#     'id': 1186381103,
#     'type': 'C'},
#    'abstract': 'During the twentieth century, it became clear that national economies can make progress only by investing in human capital. Knowledge increases human productivity and creativity, and society can prosper only through human self awareness, understanding of the world around them and by increasing the quality of their lives. In the information age, progress was made through information and technology, with particular emphasis on critical thinking. But in the conceptual economy of the 21st century, influenced by three key developments; over-supply, outsourcing, and automation, it has become clear that critical thinking, even with the help of high technology, is no longer sufficient to make a living or to be competitive in the labor market. In the u0027Value age,u0027 these capabilities need to be complemented by highly conceptual and highly sensitive traits. The integration of critical and creative thinking is a fundamental factor in personal productivity and the essential condition for achieving sustainable economic development. The self assessment of Algebra University College students was designed to investigate the extent to which students integrated critical and creative thinking into their own circumstances and to explore whether there is a correlation between the type of thinking they are more inclined to and their study programs. ',
#    'references': '',
#    'nb_references': 0}},
#  {'_index': 'dblp1',
#   '_type': '_doc',
#   '_id': '2168257338',
#   '_score': 13.724031,
#   '_source': {'id': 2168257338,
#    'authors': [{'name': 'Martin Sraga',
#      'org': 'Univ. Coll. Algebra, Zagreb, Croatia',
#      'id': 2558668495},
#     {'name': 'Norman Momcilovic',
#      'org': 'Univ. Coll. Algebra, Zagreb, Croatia',
#      'id': 2559188923},
#     {'name': 'Alberto Tekovic',
#      'org': 'Univ. Coll. Algebra, Zagreb, Croatia',
#      'id': 2628916144}],
#    'title': 'Mobile data Wi-Fi offloading',
#    'year': 2014,
#    'n_citation': 1,
#    'page_start': '1648',
#    'page_end': '1649',
#    'doc_type': 'Conference',
#    'publisher': 'IEEE',
#    'volume': '',
#    'issue': '',
#    'doi': '10.1109/MIPRO.2014.6859830',
#    'fos': [{'name': 'Computer science', 'w': 0.4257},
#     {'name': 'Usability', 'w': 0.47618},
#     {'name': 'Network layer', 'w': 0.46628},
#     {'name': 'Computer network', 'w': 0.45468},
#     {'name': 'Quality of service', 'w': 0.51706},
#     {'name': 'Quality of experience', 'w': 0.51869},
#     {'name': 'Small cell', 'w': 0.60757},
#     {'name': 'Mobile broadband', 'w': 0.55409},
#     {'name': 'Mobile telephony', 'w': 0.532},
#     {'name': 'The Internet', 'w': 0.48014}],
#    'venue': {'raw': 'International Convention on Information and Communication Technology, Electronics and Microelectronics',
#     'id': 1186381103,
#     'type': 'C'},
#    'abstract': 'The predicted exponential growth of mobile data traffic demands suitable solutions for coping with the high amount of data. Increasing number of Wi-Fi enabled smartphones and Wi-Fi access becoming more widely available is opening the possibility of offloading a large chunk of data traffic from 3G/ 4G mobile networks to Wi-Fi IEEE 802.11. However, the quality of experience must be preserved no matter which network layer is currently engaged. Therefore, the scope of this paper was to determine the usability of the free of charge Wi-Fi available networks and to compare it with the legacy 3G\\4G networks. ',
#    'references': '',
#    'nb_references': 0,
#    'author': {'name': '', 'id': '', 'org': ''}}},
#  {'_index': 'dblp1',
#   '_type': '_doc',
#   '_id': '2931205801',
#   '_score': 13.690258,
#   '_source': {'id': 2931205801,
#    'authors': [{'name': 'Leo Mrsic',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 1702538714},
#     {'name': 'Srecko Zajec',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 2926343397},
#     {'name': 'Robert Kopal',
#      'org': 'Algebra University College, Zagreb, Croatia',
#      'id': 1688051458}],
#    'title': 'Appliance of Social Network Analysis and Data Visualization Techniques in Analysis of Information Propagation',
#    'year': 2019,
#    'n_citation': 0,
#    'page_start': '131',
#    'page_end': '143',
#    'doc_type': 'Conference',
#    'publisher': 'Springer International Publishing',
#    'volume': '',
#    'issue': '',
#    'doi': '10.1007/978-3-030-14802-7_11',
#    'references': [1996571735,
#     1997266305,
#     2007138946,
#     2068927523,
#     2084080071,
#     2135844668],
#    'fos': [{'name': 'Data science', 'w': 0.47821},
#     {'name': 'Data mining', 'w': 0.46067},
#     {'name': 'Data processing', 'w': 0.49429},
#     {'name': 'Data visualization', 'w': 0.63427},
#     {'name': 'Social network', 'w': 0.60854},
#     {'name': 'Visualization', 'w': 0.59653},
#     {'name': 'Computer science', 'w': 0.46114},
#     {'name': 'Social network analysis', 'w': 0.58459},
#     {'name': 'Premise', 'w': 0.4544},
#     {'name': 'Information warfare', 'w': 0.53473},
#     {'name': 'Information propagation', 'w': 0.0}],
#    'venue': {'raw': 'Asian Conference on Intelligent Information and Database Systems',
#     'id': 1123338449,
#     'type': 'C'},
#    'abstract': 'This paper explains appliance of social network analysis and data visualization techniques in analysis of information propagation. Context of information (news) propagation through social network is an extremely dynamic and complex area to study. Due to topic actuality and a very small number of works on the similar topic this paper required a comprehensive and systematic approach. Thus, for practical reasons this work is based on the usage of Social Network Analysis (SNA) and visualization of social networking data obtained through Facebook covering 145 + public pages linked to 2.6 million fans. The main hypothesis is based on the premise whether is possible to find any similarities between the real-life social, economic and political entities/processes and online information propagation. The process consists of the development of the underlying model, the retrieval of data, data processing and consequential analysis u0026 visualization which has been elaborated in detail along with the comments related to the methods of application. ',
#    'nb_references': 6}},
#  {'_index': 'dblp1',
#   '_type': '_doc',
#   '_id': '2167183102',
#   '_score': 13.529454,
#   '_source': {'id': 2167183102,
#    'authors': [{'name': 'Gert-Martin Greuel',
#      'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany',
#      'id': 2125494213},
#     {'name': 'Frank Seelisch',
#      'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany',
#      'id': 341850799},
#     {'name': 'Oliver Wienand',
#      'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany',
#      'id': 64692017}],
#    'title': 'The Gröbner basis of the ideal of vanishing polynomials',
#    'year': 2011,
#    'n_citation': 14,
#    'page_start': '561',
#    'page_end': '570',
#    'doc_type': 'Journal',
#    'publisher': 'Academic Press',
#    'volume': '46',
#    'issue': '5',
#    'doi': '10.1016/j.jsc.2010.10.006',
#    'references': [1844774176, 1975573855, 2104976591],
#    'fos': [{'name': 'Discrete mathematics', 'w': 0.47497},
#     {'name': 'Monomial order', 'w': 0.63313},
#     {'name': 'Combinatorics', 'w': 0.47143},
#     {'name': 'Recursion (computer science)', 'w': 0.45455},
#     {'name': 'Algebra', 'w': 0.47425},
#     {'name': 'Polynomial', 'w': 0.57494},
#     {'name': 'Polynomial ring', 'w': 0.57519},
#     {'name': 'Multiplication', 'w': 0.50153},
#     {'name': 'Gröbner basis', 'w': 0.61711},
#     {'name': 'Prime factor', 'w': 0.55667},
#     {'name': 'Mathematics', 'w': 0.4282},
#     {'name': 'Formal verification', 'w': 0.45669}],
#    'venue': {'raw': 'Journal of Symbolic Computation',
#     'id': 18904315,
#     'type': 'J'},
#    'abstract': 'We construct an explicit minimal strong Grobner basis of the ideal of vanishing polynomials in the polynomial ring over Z/m for mu003e=2. The proof is done in a purely combinatorial way. It is a remarkable fact that the constructed Grobner basis is independent of the monomial order and that the set of leading terms of the constructed Grobner basis is unique, up to multiplication by units. We also present a fast algorithm to compute reduced normal forms, and furthermore, we give a recursive algorithm for building a Grobner basis in Z/m[x"1,x"2,...,x"n] along the prime factorization of m. The obtained results are not only of mathematical interest but have immediate applications in formal verification of data paths for microelectronic systems-on-chip. ',
#    'nb_references': 3}}]

# %%
# The abstract in the paper are needed to be accessed in order to compare the difficulty of the words used

abstracts = []
for paper in papers:
    abstracts.append(paper['_source']['abstract'])
# Out:
# {'_index': 'dblp1', '_type': '_doc', '_id': '2956661043', '_score': 13.840944, '_source': {'id': 2956661043, 'authors': [{'name': 'Tihana Babic', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 2810252259}, {'name': 'Andrej Lackovic', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 2956200875}, {'name': 'Martina Matejic', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 2946534387}], 'title': 'Critical Thinking and Creative Thinking - the self-assessment of Algebra University College students', 'year': 2019, 'n_citation': 0, 'page_start': '843', 'page_end': '848', 'doc_type': 'Conference', 'publisher': 'IEEE', 'volume': '', 'issue': '', 'doi': '10.23919/MIPRO.2019.8757107', 'fos': [{'name': 'Self-assessment', 'w': 0.46724}, {'name': 'Conceptual economy', 'w': 0.56208}, {'name': 'Algebra', 'w': 0.33293}, {'name': 'Computer science', 'w': 0.38773}, {'name': 'Outsourcing', 'w': 0.46447}, {'name': 'Critical thinking', 'w': 0.65965}, {'name': 'Self', 'w': 0.47672}, {'name': 'Human capital', 'w': 0.50811}, {'name': 'Creativity', 'w': 0.55269}, {'name': 'Information Age', 'w': 0.51277}], 'venue': {'raw': 'International Convention on Information and Communication Technology, Electronics and Microelectronics', 'id': 1186381103, 'type': 'C'}, 'abstract': 'During the twentieth century, it became clear that national economies can make progress only by investing in human capital. Knowledge increases human productivity and creativity, and society can prosper only through human self awareness, understanding of the world around them and by increasing the quality of their lives. In the information age, progress was made through information and technology, with particular emphasis on critical thinking. But in the conceptual economy of the 21st century, influenced by three key developments; over-supply, outsourcing, and automation, it has become clear that critical thinking, even with the help of high technology, is no longer sufficient to make a living or to be competitive in the labor market. In the u0027Value age,u0027 these capabilities need to be complemented by highly conceptual and highly sensitive traits. The integration of critical and creative thinking is a fundamental factor in personal productivity and the essential condition for achieving sustainable economic development. The self assessment of Algebra University College students was designed to investigate the extent to which students integrated critical and creative thinking into their own circumstances and to explore whether there is a correlation between the type of thinking they are more inclined to and their study programs. ', 'references': '', 'nb_references': 0}}
# {'_index': 'dblp1', '_type': '_doc', '_id': '2168257338', '_score': 13.724031, '_source': {'id': 2168257338, 'authors': [{'name': 'Martin Sraga', 'org': 'Univ. Coll. Algebra, Zagreb, Croatia', 'id': 2558668495}, {'name': 'Norman Momcilovic', 'org': 'Univ. Coll. Algebra, Zagreb, Croatia', 'id': 2559188923}, {'name': 'Alberto Tekovic', 'org': 'Univ. Coll. Algebra, Zagreb, Croatia', 'id': 2628916144}], 'title': 'Mobile data Wi-Fi offloading', 'year': 2014, 'n_citation': 1, 'page_start': '1648', 'page_end': '1649', 'doc_type': 'Conference', 'publisher': 'IEEE', 'volume': '', 'issue': '', 'doi': '10.1109/MIPRO.2014.6859830', 'fos': [{'name': 'Computer science', 'w': 0.4257}, {'name': 'Usability', 'w': 0.47618}, {'name': 'Network layer', 'w': 0.46628}, {'name': 'Computer network', 'w': 0.45468}, {'name': 'Quality of service', 'w': 0.51706}, {'name': 'Quality of experience', 'w': 0.51869}, {'name': 'Small cell', 'w': 0.60757}, {'name': 'Mobile broadband', 'w': 0.55409}, {'name': 'Mobile telephony', 'w': 0.532}, {'name': 'The Internet', 'w': 0.48014}], 'venue': {'raw': 'International Convention on Information and Communication Technology, Electronics and Microelectronics', 'id': 1186381103, 'type': 'C'}, 'abstract': 'The predicted exponential growth of mobile data traffic demands suitable solutions for coping with the high amount of data. Increasing number of Wi-Fi enabled smartphones and Wi-Fi access becoming more widely available is opening the possibility of offloading a large chunk of data traffic from 3G/ 4G mobile networks to Wi-Fi IEEE 802.11. However, the quality of experience must be preserved no matter which network layer is currently engaged. Therefore, the scope of this paper was to determine the usability of the free of charge Wi-Fi available networks and to compare it with the legacy 3G\\4G networks. ', 'references': '', 'nb_references': 0, 'author': {'name': '', 'id': '', 'org': ''}}}
# {'_index': 'dblp1', '_type': '_doc', '_id': '2931205801', '_score': 13.690258, '_source': {'id': 2931205801, 'authors': [{'name': 'Leo Mrsic', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 1702538714}, {'name': 'Srecko Zajec', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 2926343397}, {'name': 'Robert Kopal', 'org': 'Algebra University College, Zagreb, Croatia', 'id': 1688051458}], 'title': 'Appliance of Social Network Analysis and Data Visualization Techniques in Analysis of Information Propagation', 'year': 2019, 'n_citation': 0, 'page_start': '131', 'page_end': '143', 'doc_type': 'Conference', 'publisher': 'Springer International Publishing', 'volume': '', 'issue': '', 'doi': '10.1007/978-3-030-14802-7_11', 'references': [1996571735, 1997266305, 2007138946, 2068927523, 2084080071, 2135844668], 'fos': [{'name': 'Data science', 'w': 0.47821}, {'name': 'Data mining', 'w': 0.46067}, {'name': 'Data processing', 'w': 0.49429}, {'name': 'Data visualization', 'w': 0.63427}, {'name': 'Social network', 'w': 0.60854}, {'name': 'Visualization', 'w': 0.59653}, {'name': 'Computer science', 'w': 0.46114}, {'name': 'Social network analysis', 'w': 0.58459}, {'name': 'Premise', 'w': 0.4544}, {'name': 'Information warfare', 'w': 0.53473}, {'name': 'Information propagation', 'w': 0.0}], 'venue': {'raw': 'Asian Conference on Intelligent Information and Database Systems', 'id': 1123338449, 'type': 'C'}, 'abstract': 'This paper explains appliance of social network analysis and data visualization techniques in analysis of information propagation. Context of information (news) propagation through social network is an extremely dynamic and complex area to study. Due to topic actuality and a very small number of works on the similar topic this paper required a comprehensive and systematic approach. Thus, for practical reasons this work is based on the usage of Social Network Analysis (SNA) and visualization of social networking data obtained through Facebook covering 145 + public pages linked to 2.6 million fans. The main hypothesis is based on the premise whether is possible to find any similarities between the real-life social, economic and political entities/processes and online information propagation. The process consists of the development of the underlying model, the retrieval of data, data processing and consequential analysis u0026 visualization which has been elaborated in detail along with the comments related to the methods of application. ', 'nb_references': 6}}
# {'_index': 'dblp1', '_type': '_doc', '_id': '2167183102', '_score': 13.529454, '_source': {'id': 2167183102, 'authors': [{'name': 'Gert-Martin Greuel', 'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany', 'id': 2125494213}, {'name': 'Frank Seelisch', 'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany', 'id': 341850799}, {'name': 'Oliver Wienand', 'org': 'Department of Mathematics, Working Group Algebra, Geometry, and Computer Algebra, University of Kaiserslautern, Germany', 'id': 64692017}], 'title': 'The Gröbner basis of the ideal of vanishing polynomials', 'year': 2011, 'n_citation': 14, 'page_start': '561', 'page_end': '570', 'doc_type': 'Journal', 'publisher': 'Academic Press', 'volume': '46', 'issue': '5', 'doi': '10.1016/j.jsc.2010.10.006', 'references': [1844774176, 1975573855, 2104976591], 'fos': [{'name': 'Discrete mathematics', 'w': 0.47497}, {'name': 'Monomial order', 'w': 0.63313}, {'name': 'Combinatorics', 'w': 0.47143}, {'name': 'Recursion (computer science)', 'w': 0.45455}, {'name': 'Algebra', 'w': 0.47425}, {'name': 'Polynomial', 'w': 0.57494}, {'name': 'Polynomial ring', 'w': 0.57519}, {'name': 'Multiplication', 'w': 0.50153}, {'name': 'Gröbner basis', 'w': 0.61711}, {'name': 'Prime factor', 'w': 0.55667}, {'name': 'Mathematics', 'w': 0.4282}, {'name': 'Formal verification', 'w': 0.45669}], 'venue': {'raw': 'Journal of Symbolic Computation', 'id': 18904315, 'type': 'J'}, 'abstract': 'We construct an explicit minimal strong Grobner basis of the ideal of vanishing polynomials in the polynomial ring over Z/m for mu003e=2. The proof is done in a purely combinatorial way. It is a remarkable fact that the constructed Grobner basis is independent of the monomial order and that the set of leading terms of the constructed Grobner basis is unique, up to multiplication by units. We also present a fast algorithm to compute reduced normal forms, and furthermore, we give a recursive algorithm for building a Grobner basis in Z/m[x"1,x"2,...,x"n] along the prime factorization of m. The obtained results are not only of mathematical interest but have immediate applications in formal verification of data paths for microelectronic systems-on-chip. ', 'nb_references': 3}}
