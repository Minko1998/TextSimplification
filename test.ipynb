# %%
import wget
import pandas as pd

# %%
# !wget -O dblp.json --no-check-certificate https://inex:qatc2011@guacamole.univ-avignon.fr/dblp1/_search?size=10000
# Out:
# --2022-04-19 12:40:59--  https://inex:*password*@guacamole.univ-avignon.fr/dblp1/_search?size=10000
# Resolving guacamole.univ-avignon.fr (guacamole.univ-avignon.fr)... 194.57.216.245
# Connecting to guacamole.univ-avignon.fr (guacamole.univ-avignon.fr)|194.57.216.245|:443... connected.
# WARNING: cannot verify guacamole.univ-avignon.fr's certificate, issued by ‘CN=TERENA SSL CA 3,O=TERENA,L=Amsterdam,ST=Noord-Holland,C=NL’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="CLEF SimpleText. Contact: eric.sanjuan@univ-avignon.fr"
# Reusing existing connection to guacamole.univ-avignon.fr:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17239381 (16M) [application/json]
# Saving to: ‘dblp.json’
#
# dblp.json           100%[===================>]  16,44M  6,14MB/s    in 2,7s
#
# 2022-04-19 12:41:02 (6,14 MB/s) - ‘dblp.json’ saved [17239381/17239381]

# %%
#!wget -O dblp.json --no-check-certificate https://inex:qatc2011@guacamole.univ-avignon.fr/dblp1/_search
# Out:
# --2022-04-19 12:40:19--  https://inex:*password*@guacamole.univ-avignon.fr/dblp1/_search
# Resolving guacamole.univ-avignon.fr (guacamole.univ-avignon.fr)... 194.57.216.245
# Connecting to guacamole.univ-avignon.fr (guacamole.univ-avignon.fr)|194.57.216.245|:443... connected.
# WARNING: cannot verify guacamole.univ-avignon.fr's certificate, issued by ‘CN=TERENA SSL CA 3,O=TERENA,L=Amsterdam,ST=Noord-Holland,C=NL’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="CLEF SimpleText. Contact: eric.sanjuan@univ-avignon.fr"
# Reusing existing connection to guacamole.univ-avignon.fr:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13223 (13K) [application/json]
# Saving to: ‘dblp.json’
#
# dblp.json           100%[===================>]  12,91K  --.-KB/s    in 0,009s
#
# 2022-04-19 12:40:19 (1,41 MB/s) - ‘dblp.json’ saved [13223/13223]

# %%
df = pd.read_csv('dblp.csv', )

col = df.columns
col

# title = df.hits__hits___source__title
# title = title.dropna()
# title = title.tolist()

# author = df.hits__hits___source__authors__name
# author = author.dropna()
# author = author.tolist()

# year = df.hits__hits___source__year
# year = year.dropna()
# year = year.astype(int)
# year = year.tolist()

# abstract = df.hits__hits___source__abstract
# abstract = abstract.dropna()
# abstract = abstract.tolist()

# df = df[['hits__hits___source__title',
#          'hits__hits___source__authors__name',
#          'hits__hits___source__year',
#          'hits__hits___source__abstract']]
# df.rename(columns = {'hits__hits___source__title':'title',
#                      'hits__hits___source__authors__name':'author',
#                      'hits__hits___source__year':'year', 
#                      'hits__hits___source__abstract':'abstract'},
#           inplace = True)

# df = df.dropna()
# df.year = df.year.astype(int)
# df
# Out:
# Index(['took', 'timed_out', '_shards__total', '_shards__successful',
#        '_shards__skipped', '_shards__failed', 'hits__total__value',
#        'hits__total__relation', 'hits__max_score', 'hits__hits___index',
#        'hits__hits___type', 'hits__hits___id', 'hits__hits___score',
#        'hits__hits___source__id', 'hits__hits___source__authors__name',
#        'hits__hits___source__authors__org', 'hits__hits___source__authors__id',
#        'hits__hits___source__title', 'hits__hits___source__year',
#        'hits__hits___source__n_citation', 'hits__hits___source__page_start',
#        'hits__hits___source__page_end', 'hits__hits___source__doc_type',
#        'hits__hits___source__publisher', 'hits__hits___source__volume',
#        'hits__hits___source__issue', 'hits__hits___source__doi',
#        'hits__hits___source__references__-', 'hits__hits___source__fos__name',
#        'hits__hits___source__fos__w', 'hits__hits___source__venue__raw',
# ...

# %%
df = pd.read_csv('dblp.csv')
df = df[['hits__hits___source__title',
         'hits__hits___source__authors__name',
         'hits__hits___source__year',
         'hits__hits___source__abstract']]
df.rename(columns = {'hits__hits___source__title':'title',
                     'hits__hits___source__authors__name':'author',
                     'hits__hits___source__year':'year', 
                     'hits__hits___source__abstract':'abstract'},
          inplace = True)

df = df.dropna()
df.year = df.year.astype(int)
df
# Out:
#                                                  title  \
# 5    Linking Operational Semantics and Algebraic Se...
# 15           On (p, q)-analogue of Bernstein operators
# 35   Exploring Low Dimensional Objects in High Dime...
# 50   A System of Umpires for Security of Wireless M...
# 69                          Type-2 Fuzzy Logic Systems
# 79   Fredholm-Volterra integral equation with singu...
# 89   A Framework to Promote and Develop a Sustainab...
# 98   Nonlinear signal processing and nonuniform lin...
# 111  Implementation of Stable Skew–Symmetric Matrix...
# 141  Research on Behavioral Semanteme Form Based on...
# 164          Closest-Point Queries for Complex Objects
# 198                                   Better than SIFT
# 251  Diagrammatic Analysis of Interval Linear Equat...
# 266  A Steady State Model for the Transcriptional R...
# 277  Examining Effects of Cognitive Style on Techno...
# 296  Caregiving burden responses differ for Interne...
# ...
